# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# Objective:
# - Understand dataset structure
# - Identify target variable (churn)
# - Detect missing values and data issues

# %%
import pandas as pd 
import seaborn as sns

# %%
file_path = r"F:\retailgenius-churn-ai\src\data\raw\E_Commerce_Dataset.xlsx"

df = pd.read_excel(file_path)

# %%
xls = pd.ExcelFile(file_path)
print(xls.sheet_names)
# Out:
# ['Data Dict', 'E Comm']

# %%
# reading the file from Excel sheet
df = pd.read_excel(file_path, sheet_name="E Comm")
df.head(5)
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
# shape of the E comm 
df.shape
# Out:
# (5630, 20)

# %%
# overview of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %% [markdown]
# ## Dataset Overview
#
#
# - Number of rows: 5630 rows are available
#
# - Number of columns: 20 number of colums
#
# - Target variable: churn (Yes/No or 0/1)
#
# - Numerical features: Tenure,OrderCount,CityTier,SatisfactionScore,OrderAmountHikeFromlastYear,CashbackAmount
#
# - Categorical features: CustomerID,Gender,PreferredLoginDevice,PreferredPaymentMode,Gender,PreferedOrderCat,MaritalStatus

# %% [markdown]
# ## Churn Definition
#
# In this project, a customer is considered churned if they stop purchasing
#
# or interacting with the platform for a defined period.
#
# The churn label provided in the dataset is used as the ground truth for supervised learning.
#
# This shows business understanding, not just coding.

# %%
# checking for the null value count
df.isnull().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
# to get the value of the churn customer 
df['Churn'].value_counts()
# Out:
# Churn
# 0    4682
# 1     948
# Name: count, dtype: int64

# %%
# to plot the Churn count 
sns.countplot(x='Churn', data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>
